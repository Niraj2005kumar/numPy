# %%
print("hello")
# Out:
# hello

# %%
print("How are you")
# Out:
# How are you

# %%
def hello():
    print("How are you")

# %%
hello()
# Out:
# How are you

# %%
number = [1,2,3,]
print(number)
# Out:
# [1, 2, 3]
