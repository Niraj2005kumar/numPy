# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Matplotlib is a library in Python that is used for data visualization. It provides a wide range of tools and functions to create various types of plots and charts, such as line plots, bar plots, scatter plots, histograms, and more. Matplotlib is highly customizable, allowing users to adjust the appearance of their plots, including colors, labels, titles, and axes. It is widely used in data analysis, scientific research, and machine learning to visualize data and gain insights from it.

x = np.linspace(0, 5, 11)
x
y = x ** 3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x, y)   # esse graph draw kr sakte hai graph ke under 
plt.xlabel('X Label')  # x axis ka label
plt.ylabel('Y Label')  # y axis ka label
plt.title('Title')  # graph ka title(naam likh sakte hai esse )
# Out:
# Text(0.5, 1.0, 'Title')

# %%
#subplots :- MAtlab ki ek hi graph ke ander multiple graph draw kr sakte hai




plt.subplot(2, 2, 2)  # 2 row and 2 column me graph draw hoga aur 1st graph draw hoga
plt.plot(x, y)  #esko likhne pr graph ke under graph draw hoga
plt.subplot(2, 2, 1)
plt.plot(y, x)
plt.subplot(2, 2, 3)
plt.plot(x**2 , y**2)  #esse straight line draw hoga graph ke under
plt.subplot(2, 2, 4)
# Out:
# <Axes: >

# %%
#Object Oriented Method :- Isme hum graph ke ander graph draw karte hai aur graph ke ander graph draw karne ke liye hum figure ka use karte hai

fig = plt.Figure(figsize=(20, 8), dpi=100) 

fig = plt.figure()  # esse graph ke ander graph draw hoga
axis1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])  # esse graph ke ander graph draw hoga
axis1.plot(x, y)  # esse graph ke ander graph draw hoga
axis1 = fig.add_axes([0.1, 0.1, 0.4, 0.4])  # esse graph ke ander graph draw hoga
axis1.plot(x, y)  # esse graph ke ander graph draw hoga

# %%
#Type of Plots :- Matplotlib me alag alag type ke plots draw kr sakte hai jaise ki line plot, bar plot, scatter plot, histogram, pie chart, etc.
plt.scatter(x, y)  # esse scatter plot draw hoga

# %%
from random import sample
data = sample(range(1, 1000), 100)  # esse random data generate hoga

plt.hist(data)  # esse histogram draw hoga
# Out:
# (array([17., 10.,  8., 12.,  8., 13., 10.,  5.,  7., 10.]),
#  array([  2. , 101.4, 200.8, 300.2, 399.6, 499. , 598.4, 697.8, 797.2,
#         896.6, 996. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28b56cb57f0>,
#   <matplotlib.lines.Line2D at 0x28b56cb5940>],
#  'caps': [<matplotlib.lines.Line2D at 0x28b56cb5a90>,
#   <matplotlib.lines.Line2D at 0x28b56cb5be0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28b56cb56a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x28b56cb5d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28b56cb5e80>],
#  'means': []}

# %% [markdown]
# Saving PLots

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.plot(x, y)
plt.savefig('mygraph.png')  # esse graph save hoga

# %% [markdown]
# Working with image

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread('mygraph.png') 
plt.imshow(img) 
plt.axis("off")# esse graph read hoga
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(479.5), np.float64(-0.5))

# %%
cropped_img = img[100:400, 100:400]  # esse image ko crop kiya ja sakta hai
plt.imshow(cropped_img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %% [markdown]
# OPTIONAL DESIGNING

# %%
xaxis = np.linspace(0, 5, 11)

fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(xaxis, xaxis + 1, color="red", linewidth=0.25)
ax.plot(xaxis, xaxis + 3, color="red", linewidth=0.50)
ax.plot(xaxis, xaxis + 5, color="red", linewidth=1.00)
ax.plot(xaxis, xaxis + 7, color="red", linewidth=2.00)

ax.plot(xaxis, xaxis + 8, color="green", lw=3, linestyle='-')
ax.plot(xaxis, xaxis + 9, color="green", lw=3, linestyle='--')
ax.plot(xaxis, xaxis + 10, color="green", lw=3, linestyle=':')

line, = ax.plot(xaxis, xaxis + 8, color="black", lw=1.50)
line.set_dashes([5, 15, 15, 5])

ax.plot(xaxis, xaxis + 9, color="blue", lw=3, ls='-', marker='o')
ax.plot(xaxis, xaxis + 10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis + 11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis + 12, color="blue", lw=3, ls='-', marker='^')
ax.plot(xaxis, xaxis + 13, color="blue", lw=3, ls='-', marker='*')

ax.plot(xaxis, xaxis + 14, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis + 15, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis + 16, color="purple", lw=1, ls='-', marker='o', markersize=8)

ax.plot(xaxis, xaxis + 17,color="purple",lw=1,ls='-',marker='o',markersize=8,markerfacecolor="red")

ax.plot(
    xaxis, xaxis + 18,
    color="purple",
    lw=1,
    ls='-',
    marker='o',
    markersize=8,
    markerfacecolor="yellow",
    markeredgewidth=3,
    markeredgecolor="green"
)

plt.show()
