# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Name": ["Niraj", "Rahul", "Aman", "Priya", "Neha", "Riya"],
    "Department": ["IT", "IT", "HR", "HR", "IT", "HR"],
    "Marks": [85, 78, 92, 88, 90, 95]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Name Department  Marks
# 0  Niraj         IT     85
# 1  Rahul         IT     78
# 2   Aman         HR     92
# 3  Priya         HR     88
# 4   Neha         IT     90
# 5   Riya         HR     95
